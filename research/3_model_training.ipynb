# %%
import os

# %%
# %pwd
# Out:
# 'd:\\Kidney-Disease-Classification\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\Kidney-Disease-Classification'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class TrainingConfig:
    root_dir: Path
    trained_model_path: Path
    updated_base_model_path: Path
    training_data: Path
    params_epochs: int
    params_batch_size: int
    params_is_augmentation: bool
    params_image_size: list

# %%
from KdiseaseClassifier.constants import *
from KdiseaseClassifier.utils.common import read_yaml, create_directories
import tensorflow as tf

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_training_config(self) -> TrainingConfig:
        training = self.config.training
        prepare_base_model = self.config.prepare_base_model
        params = self.params
        training_data = os.path.join(self.config.data_ingestion.unzip_dir, "kidney-ct-scan-image")
        create_directories([
            Path(training.root_dir)
        ])

        training_config = TrainingConfig(
            root_dir=Path(training.root_dir),
            trained_model_path=Path(training.trained_model_path),
            updated_base_model_path=Path(prepare_base_model.updated_base_model_path),
            training_data=Path(training_data),
            params_epochs=params.EPOCHS,
            params_batch_size=params.BATCH_SIZE,
            params_is_augmentation=params.AUGMENTATION,
            params_image_size=params.IMAGE_SIZE
        )

        return training_config

# %%
import os
import urllib.request as request
from zipfile import ZipFile
import time

# %%
class Training:
    def __init__(self, config: TrainingConfig):
        self.config = config

    
    def get_base_model(self):
        self.model = tf.keras.models.load_model(
            self.config.updated_base_model_path
        )

    def train_valid_generator(self):

        datagenerator_kwargs = dict(
            rescale = 1./255,
            validation_split=0.20
        )

        dataflow_kwargs = dict(
            target_size=self.config.params_image_size[:-1],
            batch_size=self.config.params_batch_size,
            interpolation="bilinear"
        )

        valid_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
            **datagenerator_kwargs
        )

        self.valid_generator = valid_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="validation",
            shuffle=False,
            **dataflow_kwargs
        )

        if self.config.params_is_augmentation:
            train_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
                rotation_range=40,
                horizontal_flip=True,
                width_shift_range=0.2,
                height_shift_range=0.2,
                shear_range=0.2,
                zoom_range=0.2,
                **datagenerator_kwargs
            )
        else:
            train_datagenerator = valid_datagenerator

        self.train_generator = train_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="training",
            shuffle=True,
            **dataflow_kwargs
        )

    
    @staticmethod
    def save_model(path: Path, model: tf.keras.Model):
        model.save(path)



    
    def train(self):
        self.steps_per_epoch = self.train_generator.samples // self.train_generator.batch_size
        self.validation_steps = self.valid_generator.samples // self.valid_generator.batch_size

        self.model.fit(
            self.train_generator,
            epochs=self.config.params_epochs,
            steps_per_epoch=self.steps_per_epoch,
            validation_steps=self.validation_steps,
            validation_data=self.valid_generator
        )

        self.save_model(
            path=self.config.trained_model_path,
            model=self.model
        )

# %%
try:
    config = ConfigurationManager()
    training_config = config.get_training_config()
    training = Training(config=training_config)
    training.get_base_model()
    training.train_valid_generator()
    training.train()
    
except Exception as e:
    raise e
# Out:
# [2025-05-29 15:59:26,443: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2025-05-29 15:59:26,476: INFO: common: yaml file: params.yaml loaded successfully]
# [2025-05-29 15:59:26,482: INFO: common: created directory at: artifacts]
# [2025-05-29 15:59:26,482: INFO: common: created directory at: artifacts\training]
# Found 93 images belonging to 2 classes.
# Found 372 images belonging to 2 classes.
# Epoch 1/100
# 23/23 [==============================] - 45s 2s/step - loss: 2.4737 - accuracy: 0.4972 - val_loss: 0.7406 - val_accuracy: 0.4375
# Epoch 2/100
# 23/23 [==============================] - 31s 1s/step - loss: 1.9795 - accuracy: 0.4944 - val_loss: 4.5796 - val_accuracy: 0.4000
# Epoch 3/100
# 23/23 [==============================] - 30s 1s/step - loss: 1.9659 - accuracy: 0.5028 - val_loss: 2.9433 - val_accuracy: 0.4000
# Epoch 4/100
# 23/23 [==============================] - 30s 1s/step - loss: 2.1575 - accuracy: 0.4579 - val_loss: 0.8159 - val_accuracy: 0.6000
# Epoch 5/100
# 23/23 [==============================] - 30s 1s/step - loss: 1.8491 - accuracy: 0.5084 - val_loss: 3.4704 - val_accuracy: 0.4000
# Epoch 6/100
# 23/23 [==============================] - 30s 1s/step - loss: 1.7960 - accuracy: 0.5056 - val_loss: 2.4232 - val_accuracy: 0.6000
# Epoch 7/100
# 23/23 [==============================] - 31s 1s/step - loss: 1.8206 - accuracy: 0.5109 - val_loss: 0.7287 - val_accuracy: 0.6000
# Epoch 8/100
# 23/23 [==============================] - 31s 1s/step - loss: 1.7844 - accuracy: 0.5169 - val_loss: 2.3086 - val_accuracy: 0.6000
# Epoch 9/100
# 23/23 [==============================] - 31s 1s/step - loss: 1.8323 - accuracy: 0.5000 - val_loss: 2.3034 - val_accuracy: 0.4000
# Epoch 10/100
# 23/23 [==============================] - 32s 1s/step - loss: 1.0261 - accuracy: 0.6461 - val_loss: 2.1495 - val_accuracy: 0.6000
# Epoch 11/100
# 23/23 [==============================] - 31s 1s/step - loss: 1.3402 - accuracy: 0.5562 - val_loss: 1.3628 - val_accuracy: 0.6000
# Epoch 12/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.9958 - accuracy: 0.6264 - val_loss: 2.5047 - val_accuracy: 0.4625
# Epoch 13/100
# 23/23 [==============================] - 30s 1s/step - loss: 1.0689 - accuracy: 0.6011 - val_loss: 2.3228 - val_accuracy: 0.4750
# Epoch 14/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.9208 - accuracy: 0.6826 - val_loss: 2.7926 - val_accuracy: 0.4500
# Epoch 15/100
# 23/23 [==============================] - 30s 1s/step - loss: 1.1004 - accuracy: 0.6348 - val_loss: 1.3809 - val_accuracy: 0.6000
# Epoch 16/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.9923 - accuracy: 0.6545 - val_loss: 2.6962 - val_accuracy: 0.4750
# Epoch 17/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.9797 - accuracy: 0.6545 - val_loss: 0.6322 - val_accuracy: 0.5375
# Epoch 18/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.7935 - accuracy: 0.6938 - val_loss: 1.3107 - val_accuracy: 0.4375
# Epoch 60/100
# 23/23 [==============================] - 34s 1s/step - loss: 0.7152 - accuracy: 0.7303 - val_loss: 0.3648 - val_accuracy: 0.9625
# Epoch 61/100
# 23/23 [==============================] - 33s 1s/step - loss: 0.5149 - accuracy: 0.7893 - val_loss: 0.5407 - val_accuracy: 0.5375
# Epoch 62/100
# 23/23 [==============================] - 34s 1s/step - loss: 0.6145 - accuracy: 0.7584 - val_loss: 0.4054 - val_accuracy: 0.9625
# Epoch 63/100
# 23/23 [==============================] - 33s 1s/step - loss: 0.6392 - accuracy: 0.7697 - val_loss: 1.4397 - val_accuracy: 0.4375
# Epoch 64/100
# 23/23 [==============================] - 34s 1s/step - loss: 0.6400 - accuracy: 0.7416 - val_loss: 0.9049 - val_accuracy: 0.6000
# Epoch 65/100
# 23/23 [==============================] - 34s 1s/step - loss: 0.9193 - accuracy: 0.6685 - val_loss: 0.3148 - val_accuracy: 0.9625
# Epoch 66/100
# 23/23 [==============================] - 35s 1s/step - loss: 0.6035 - accuracy: 0.7725 - val_loss: 0.3507 - val_accuracy: 0.9625
# Epoch 67/100
# 23/23 [==============================] - 34s 1s/step - loss: 0.5661 - accuracy: 0.7781 - val_loss: 0.3463 - val_accuracy: 0.9625
# Epoch 68/100
# 23/23 [==============================] - 34s 1s/step - loss: 0.7541 - accuracy: 0.7388 - val_loss: 0.4157 - val_accuracy: 0.9000
# Epoch 69/100
# 23/23 [==============================] - 34s 1s/step - loss: 0.5008 - accuracy: 0.7669 - val_loss: 0.3311 - val_accuracy: 0.9625
# Epoch 70/100
# 23/23 [==============================] - 33s 1s/step - loss: 0.5268 - accuracy: 0.7753 - val_loss: 0.4079 - val_accuracy: 0.9000
# Epoch 71/100
# 23/23 [==============================] - 33s 1s/step - loss: 0.6065 - accuracy: 0.7640 - val_loss: 0.4196 - val_accuracy: 0.8750
# Epoch 72/100
# 23/23 [==============================] - 34s 1s/step - loss: 0.6616 - accuracy: 0.7444 - val_loss: 0.4034 - val_accuracy: 0.9625
# Epoch 73/100
# 23/23 [==============================] - 34s 1s/step - loss: 0.5003 - accuracy: 0.7978 - val_loss: 0.3044 - val_accuracy: 0.9625
# Epoch 74/100
# 23/23 [==============================] - 33s 1s/step - loss: 0.5739 - accuracy: 0.7809 - val_loss: 0.4408 - val_accuracy: 0.8000
# Epoch 75/100
# 23/23 [==============================] - 34s 1s/step - loss: 0.6771 - accuracy: 0.7528 - val_loss: 0.5696 - val_accuracy: 0.5000
# Epoch 76/100
# 23/23 [==============================] - 33s 1s/step - loss: 0.5280 - accuracy: 0.7837 - val_loss: 1.4933 - val_accuracy: 0.4750
# Epoch 77/100
# 23/23 [==============================] - 34s 1s/step - loss: 0.4500 - accuracy: 0.8118 - val_loss: 1.9397 - val_accuracy: 0.4750
# Epoch 78/100
# 23/23 [==============================] - 33s 1s/step - loss: 0.6067 - accuracy: 0.7584 - val_loss: 1.2863 - val_accuracy: 0.4375
# Epoch 79/100
# 23/23 [==============================] - 32s 1s/step - loss: 0.5605 - accuracy: 0.7745 - val_loss: 1.3167 - val_accuracy: 0.4500
# Epoch 80/100
# 23/23 [==============================] - 31s 1s/step - loss: 0.4779 - accuracy: 0.8034 - val_loss: 0.6588 - val_accuracy: 0.4500
# Epoch 81/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.5642 - accuracy: 0.7753 - val_loss: 0.7442 - val_accuracy: 0.4375
# Epoch 82/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.4530 - accuracy: 0.8006 - val_loss: 0.3813 - val_accuracy: 0.9000
# Epoch 83/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.5301 - accuracy: 0.7949 - val_loss: 0.3437 - val_accuracy: 0.9500
# Epoch 84/100
# 23/23 [==============================] - 31s 1s/step - loss: 0.5830 - accuracy: 0.7865 - val_loss: 0.8410 - val_accuracy: 0.4375
# Epoch 85/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.6265 - accuracy: 0.7472 - val_loss: 0.2712 - val_accuracy: 0.9625
# Epoch 86/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.4373 - accuracy: 0.7893 - val_loss: 1.8858 - val_accuracy: 0.4750
# Epoch 87/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.4832 - accuracy: 0.8118 - val_loss: 0.2598 - val_accuracy: 0.9625
# Epoch 88/100
# 23/23 [==============================] - 31s 1s/step - loss: 0.8721 - accuracy: 0.6966 - val_loss: 0.2814 - val_accuracy: 0.9625
# Epoch 89/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.5496 - accuracy: 0.7809 - val_loss: 0.4230 - val_accuracy: 0.7875
# Epoch 90/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.4177 - accuracy: 0.8090 - val_loss: 0.7390 - val_accuracy: 0.4375
# Epoch 91/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.4457 - accuracy: 0.8287 - val_loss: 0.2605 - val_accuracy: 0.9625
# Epoch 92/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.6111 - accuracy: 0.7781 - val_loss: 0.2511 - val_accuracy: 0.9625
# Epoch 93/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.5767 - accuracy: 0.7725 - val_loss: 0.9560 - val_accuracy: 0.4375
# Epoch 94/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.4437 - accuracy: 0.8062 - val_loss: 0.6378 - val_accuracy: 0.4625
# Epoch 95/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.6267 - accuracy: 0.7809 - val_loss: 0.6372 - val_accuracy: 0.4625
# Epoch 96/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.3727 - accuracy: 0.8427 - val_loss: 0.3158 - val_accuracy: 0.9625
# Epoch 97/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.5812 - accuracy: 0.7697 - val_loss: 1.5086 - val_accuracy: 0.4750
# Epoch 98/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.5010 - accuracy: 0.7725 - val_loss: 0.8180 - val_accuracy: 0.4375
# Epoch 99/100
# 23/23 [==============================] - 31s 1s/step - loss: 0.6281 - accuracy: 0.7388 - val_loss: 0.2685 - val_accuracy: 0.9625
# Epoch 100/100
# 23/23 [==============================] - 30s 1s/step - loss: 0.6817 - accuracy: 0.7303 - val_loss: 0.3870 - val_accuracy: 0.8500
